# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('C:/Users/Vilas/Downloads/HR Data.xlsx')

# %%
df.head()
# Out:
#   Attrition    Business Travel CF_age band CF_attrition label Department  \
# 0       Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1        No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2       Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3        No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4        No      Travel_Rarely     25 - 34  Current Employees        R&D
#
#   Education Field   emp no  Employee Number  Gender               Job Role  \
# 0   Life Sciences  STAFF-1                1  Female        Sales Executive
# 1   Life Sciences  STAFF-2                2    Male     Research Scientist
# 2           Other  STAFF-4                4    Male  Laboratory Technician
# 3   Life Sciences  STAFF-5                5  Female     Research Scientist
# 4         Medical  STAFF-7                7    Male  Laboratory Technician
#
#    ... Performance Rating Relationship Satisfaction Standard Hours  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 41 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Attrition                   1470 non-null   object
#  1   Business Travel             1470 non-null   object
#  2   CF_age band                 1470 non-null   object
#  3   CF_attrition label          1470 non-null   object
#  4   Department                  1470 non-null   object
#  5   Education Field             1470 non-null   object
#  6   emp no                      1470 non-null   object
#  7   Employee Number             1470 non-null   int64
#  8   Gender                      1470 non-null   object
#  9   Job Role                    1470 non-null   object
#  10  Marital Status              1470 non-null   object
#  11  Over Time                   1470 non-null   object
#  12  Over18                      1470 non-null   object
# ...

# %%
df.describe()
# Out:
#        Employee Number  Training Times Last Year      -2       0          Age  \
# count      1470.000000               1470.000000  1470.0  1470.0  1470.000000
# mean       1024.865306                  2.799320    -2.0     0.0    36.923810
# std         602.024335                  1.289271     0.0     0.0     9.135373
# min           1.000000                  0.000000    -2.0     0.0    18.000000
# 25%         491.250000                  2.000000    -2.0     0.0    30.000000
# 50%        1020.500000                  3.000000    -2.0     0.0    36.000000
# 75%        1555.750000                  3.000000    -2.0     0.0    43.000000
# max        2068.000000                  6.000000    -2.0     0.0    60.000000
#
#        CF_current Employee   Daily Rate  Distance From Home  Employee Count  \
# count          1470.000000  1470.000000         1470.000000          1470.0
# mean              0.838776   802.485714            9.192517             1.0
# ...

# %%
print(df.isnull().sum())
# Out:
# Attrition                     0
# Business Travel               0
# CF_age band                   0
# CF_attrition label            0
# Department                    0
# Education Field               0
# emp no                        0
# Employee Number               0
# Gender                        0
# Job Role                      0
# Marital Status                0
# Over Time                     0
# Over18                        0
# Training Times Last Year      0
# -2                            0
# 0                             0
# Age                           0
# CF_current Employee           0
# Daily Rate                    0
# Distance From Home            0
# Education                     0
# Employee Count                0
# Environment Satisfaction      0
# Hourly Rate                   0
# Job Involvement               0
# Job Level                     0
# Job Satisfaction              0
# Monthly Income                0
# Monthly Rate                  0
# ...

# %%
mean_age = np.mean(df['Age'])
print("Mean Age: ", mean_age)
# Out:
# Mean Age:  36.923809523809524

# %%
median_monthly_income = np.median(df['Monthly Income'])
print("Median Monthly Income:", median_monthly_income)
# Out:
# Median Monthly Income: 4919.0

# %%
std_total_working_years = np.std(df['Total Working Years'])
print("Standard Deviation of Total Working Years:", std_total_working_years)
# Out:
# Standard Deviation of Total Working Years: 7.778134700893239

# %%
df['Monthly Income Sqrt'] = np.sqrt(df['Monthly Income'])

# %%
df[['Monthly Income', 'Monthly Income Sqrt']].head()
# Out:
#    Monthly Income  Monthly Income Sqrt
# 0            5993            77.414469
# 1            5130            71.624018
# 2            2090            45.716518
# 3            2909            53.935146
# 4            3468            58.889727

# %% [markdown]
# Univariate Analysis

# %%
#Distribution of Age
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'], bins=30, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
#Distribution of Monthly Income
plt.figure(figsize=(10, 6))
sns.histplot(df['Monthly Income'], bins=30, kde=True)
plt.title('Monthly Income Distribution')
plt.xlabel('Monthly Income')
plt.ylabel('Frequency')
plt.show()

# %%
#Count of Attrition
plt.figure(figsize=(10, 6))
sns.countplot(x='Attrition', data=df)
plt.title('Attrition Count')
plt.xlabel('Attrition')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Bivariate Analysis

# %%
#Attrition by Department
plt.figure(figsize=(10, 6))
sns.countplot(x='Department', hue='Attrition', data=df)
plt.title('Attrition by Department')
plt.xlabel('Department')
plt.ylabel('Count')
plt.show()

# %%
#Attrition by Gender
plt.figure(figsize=(10, 6))
sns.countplot(x='Gender', hue='Attrition', data=df)
plt.title('Attrition by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
#Monthly Income vs. Age
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='Monthly Income', hue='Attrition', data=df)
plt.title('Monthly Income vs. Age')
plt.xlabel('Age')
plt.ylabel('Monthly Income')
plt.show()

# %% [markdown]
# Multivariate Analysis

# %%
#Pairplot of Selected Features
selected_features = ['Age', 'Monthly Income', 'Total Working Years', 'Attrition']
sns.pairplot(df[selected_features], hue='Attrition')
plt.title('Pairplot of Selected Features')
plt.show()

# %% [markdown]
# Feature Engineering

# %%
#Creating Age Bands
age_bins = [18, 25, 35, 45, 55, 65]
age_labels = ['18-24', '25-34', '35-44', '45-54', '55-65']
df['Age Band'] = pd.cut(df['Age'], bins=age_bins, labels=age_labels)

plt.figure(figsize=(10, 6))
sns.countplot(x='Age Band', hue='Attrition', data=df)
plt.title('Attrition by Age Band')
plt.xlabel('Age Band')
plt.ylabel('Count')
plt.show()

# %%
#Creating a Feature for Years Since Last Promotion
df['Years Since Last Promotion'] = df['Years At Company'] - df['Years In Current Role']

plt.figure(figsize=(10, 6))
sns.histplot(df['Years Since Last Promotion'], bins=20, kde=True)
plt.title('Years Since Last Promotion Distribution')
plt.xlabel('Years Since Last Promotion')
plt.ylabel('Frequency')
plt.show()
